# %% [markdown]
# # Multivariate 1D CNN Example

# %% [markdown]
# Based on:
# * [Time Series Forecasting on Stock Prices](https://www.youtube.com/watch?v=j05UUs99eNQ) from [Coding Tech](https://www.youtube.com/channel/UCtxCXg-UvSnTKPOzLH4wJaQ)
# * https://machinelearningmastery.com/how-to-develop-convolutional-neural-network-models-for-time-series-forecasting/

# %% [markdown]
# **Disclaimer:** _Investing in the stock market involves risk and can lead to monetary loss. This material is purely for educational purposes and should not be taken as professional investment advice. Invest at your own discretion._

# %% [markdown]
# Import the libraries

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

import matplotlib.pyplot as plt

# %% [markdown]
# Load the data

# %%
df = pd.read_csv("SP500.csv")

# %% [markdown]
# Show the data

# %%
df
# Out:
#             Date        Open        High         Low       Close   Volume  \
# 0     2000-05-19   96.106028   96.106028   94.484962   94.779701   775500
# 1     2000-05-22   94.716551   94.716551   92.169162   94.190231  1850600
# 2     2000-05-23   94.463952   94.463952   92.758675   92.758675   373900
# 3     2000-05-24   92.800753   94.358660   92.063905   94.148132   400300
# 4     2000-05-25   94.337613   94.948145   92.884970   93.284973    69600
# ...          ...         ...         ...         ...         ...      ...
# 5359  2021-09-08  452.899994  453.679993  450.869995  453.000000  4076800
# 5360  2021-09-09  452.690002  454.579987  450.730011  450.980011  3851600
# 5361  2021-09-10  453.059998  453.510010  447.299988  447.540009  3023500
# 5362  2021-09-13  450.679993  450.929993  446.089996  448.579987  3007400
# 5363  2021-09-14  450.079987  450.320007  445.200012  446.190002  3658400
#
#       Dividends  Stock Splits
# 0           0.0             0
# 1           0.0             0
# 2           0.0             0
# 3           0.0             0
# 4           0.0             0
# ...         ...           ...
# 5359        0.0             0
# 5360        0.0             0
# 5361        0.0             0
# 5362        0.0             0
# 5363        0.0             0
#
# [5364 rows x 8 columns]

# %% [markdown]
# Add indices for every day in the period

# %%
start_date = df.Date.min()
end_date = df.Date.max()

# %%
df_date = pd.date_range(start=start_date, end=end_date).to_frame(name="Date")
df_date.reset_index(drop=True, inplace=True)

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.merge(df_date, how='right')

# %% [markdown]
# Interpolate missing values

# %%
df = df.interpolate(method='linear', limit_direction='both')

# %% [markdown]
# Remove not needed columns

# %%
df = df[['Date', 'Close']].copy()

# %%
df
# Out:
#            Date       Close
# 0    2000-05-19   94.779701
# 1    2000-05-20   94.583211
# 2    2000-05-21   94.386721
# 3    2000-05-22   94.190231
# 4    2000-05-23   92.758675
# ...         ...         ...
# 7784 2021-09-10  447.540009
# 7785 2021-09-11  447.886668
# 7786 2021-09-12  448.233327
# 7787 2021-09-13  448.579987
# 7788 2021-09-14  446.190002
#
# [7789 rows x 2 columns]

# %% [markdown]
# **Simple Moving Average**
# * Example periods: 15, 30 or 45 days

# %%
def computeSMA(data, period, column='Close'):
    return data[column].rolling(window=period).mean()

# %%
df['SMA'] = computeSMA(df, period=15)

# %% [markdown]
# **Exponential Moving Averages**
# * Example periods: 15, 30 or 45 days

# %%
def computeEMA(data, period, column='Close'):
    return data[column].ewm(span=period, adjust=False).mean()

# %%
df['EMA'] = computeEMA(df, period=15)

# %% [markdown]
# **Relative Strength Index**

# %%
def computeRSI(data, period=14, column='Close'):
    delta = data[column].diff(1)
    delta = delta.dropna()
    up = delta.copy()
    down = delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0
    data['up'] = up
    data['down'] = down
    AVG_Gain = computeSMA(data, period, column='up')
    AVG_Loss = abs(computeSMA(data, period, column='down'))
    RS = AVG_Gain / AVG_Loss
    RSI = 100.0 - (100.0 / (1.0 + RS))
    return RSI

# %%
df['RSI'] = computeRSI(df, period=14)

# %% [markdown]
# **Moving Average Convergence Divergence**

# %%
def MACD(data, period1=26, period2=12, signal=9, column='Close'):
    exp1 = computeEMA(data,period1, column=column)
    exp2 = computeEMA(data,period2, column=column)
    data['MACD'] = exp2 - exp1
    data['Signal Line'] = computeSMA(data, signal, column='MACD')

# %%
MACD(df)

# %% [markdown]
# Remove NaNs

# %%
df = df.dropna()

# %%
df
# Out:
#            Date       Close         SMA         EMA        up      down  \
# 14   2000-06-02   99.663971   94.910938   95.600925  1.936874  0.000000
# 15   2000-06-03   99.446431   95.222053   96.081613  0.000000 -0.217539
# 16   2000-06-04   99.228892   95.531765   96.475023  0.000000 -0.217539
# 17   2000-06-05   99.011353   95.840074   96.792064  0.000000 -0.217539
# 18   2000-06-06   98.506065   96.127796   97.006314  0.000000 -0.505287
# ...         ...         ...         ...         ...       ...       ...
# 7784 2021-09-10  447.540009  453.257671  451.878931  0.000000 -3.440002
# 7785 2021-09-11  447.886668  452.970782  451.379898  0.346659  0.000000
# 7786 2021-09-12  448.233327  452.662337  450.986577  0.346659  0.000000
# 7787 2021-09-13  448.579987  452.332335  450.685753  0.346659  0.000000
# 7788 2021-09-14  446.190002  451.798335  450.123784  0.000000 -2.389984
#
#             RSI      MACD  Signal Line
# 14    71.245582  0.680463    -0.042866
# 15    71.115354  0.916439     0.090681
# 16    70.985601  1.073524     0.250695
# 17    70.856321  1.167008     0.420929
# 18    77.029581  1.186644     0.585988
# ...         ...       ...          ...
# 7784  30.279938  1.487905     2.619024
# 7785  28.313930  1.046934     2.394046
# 7786  26.233827  0.717167     2.129901
# 7787  24.029401  0.478284     1.844411
# 7788  20.440156  0.095020     1.527523
#
# [7775 rows x 9 columns]

# %% [markdown]
# Separate a multivariate sequence into samples

# %%
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # Find the end of the pattern
        end_ix = i + n_steps
        # Check if we are bound by sequence
        if end_ix > len(sequences) - 1:
            break
        # Gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %% [markdown]
# Define input sequence

# %%
in_seq1 = df['SMA'].values
in_seq2 = df['EMA'].values
in_seq3 = df['RSI'].values
in_seq4 = df['MACD'].values
in_seq5 = df['Signal Line'].values
out_seq = df['Close'].values

# %% [markdown]
# Convert to [rows, columns] structure

# %%
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
in_seq3 = in_seq3.reshape((len(in_seq3), 1))
in_seq4 = in_seq4.reshape((len(in_seq4), 1))
in_seq5 = in_seq5.reshape((len(in_seq5), 1))
out_seq = out_seq.reshape((len(out_seq), 1))

# %% [markdown]
# Horizontally stack columns

# %%
dataset = np.hstack((in_seq1, in_seq2, in_seq3, in_seq4, in_seq5, out_seq))

# %% [markdown]
# Choose a number of time steps

# %%
n_steps = 10

# %% [markdown]
# Convert into input/output

# %%
X, y = split_sequences(dataset, n_steps)

# %% [markdown]
# The dataset knows the number of the features, e.g. 2

# %%
n_features = X.shape[2]

# %% [markdown]
# Set test data

# %%
test_size = n_steps
prediction_size = n_features
y_test = y[-test_size-prediction_size:-prediction_size]
X_test = X[-test_size-prediction_size:-prediction_size]

# %%
y_expected = y[-prediction_size:]

# %%
y = y[:-test_size-prediction_size]
X = X[:-test_size-prediction_size]

# %% [markdown]
# Define model

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_steps, n_features)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(n_features))

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Fit model

# %%
model.fit(X, y, epochs=300)
# Out:
# Epoch 1/300
# 243/243 [==============================] - 0s 733us/step - loss: 556.5037
# Epoch 2/300
# 243/243 [==============================] - 0s 782us/step - loss: 27.9259
# Epoch 3/300
# 243/243 [==============================] - 0s 716us/step - loss: 25.4100
# Epoch 4/300
# 243/243 [==============================] - 0s 691us/step - loss: 24.8794
# Epoch 5/300
# 243/243 [==============================] - 0s 648us/step - loss: 24.1422
# Epoch 6/300
# 243/243 [==============================] - 0s 643us/step - loss: 23.8696
# Epoch 7/300
# 243/243 [==============================] - 0s 722us/step - loss: 23.7943
# Epoch 8/300
# 243/243 [==============================] - 0s 877us/step - loss: 23.5883
# Epoch 9/300
# 243/243 [==============================] - 0s 911us/step - loss: 24.1861
# Epoch 10/300
# 243/243 [==============================] - 0s 824us/step - loss: 22.0852
# Epoch 11/300
# 243/243 [==============================] - 0s 798us/step - loss: 22.3162
# Epoch 12/300
# 243/243 [==============================] - 0s 955us/step - loss: 22.8243
# Epoch 13/300
# 243/243 [==============================] - 0s 877us/step - loss: 21.9679
# Epoch 14/300
# 243/243 [==============================] - 0s 793us/step - loss: 22.1927
# Epoch 15/300
# 243/243 [==============================] - 0s 807us/step - loss: 22.7717
# Epoch 16/300
# 243/243 [==============================] - 0s 839us/step - loss: 21.5291
# Epoch 17/300
# 243/243 [==============================] - 0s 824us/step - loss: 20.9279
# Epoch 18/300
# 243/243 [==============================] - 0s 791us/step - loss: 23.2544
# Epoch 19/300
# 243/243 [==============================] - 0s 974us/step - loss: 21.5473
# Epoch 20/300
# 243/243 [==============================] - 0s 779us/step - loss: 21.8277
# Epoch 21/300
# 243/243 [==============================] - 0s 830us/step - loss: 21.0508
# Epoch 22/300
# 243/243 [==============================] - 0s 771us/step - loss: 20.8579
# Epoch 23/300
# 243/243 [==============================] - 0s 741us/step - loss: 21.3874
# Epoch 24/300
# 243/243 [==============================] - 0s 770us/step - loss: 20.2520
# Epoch 25/300
# 243/243 [==============================] - 0s 793us/step - loss: 20.4686
# Epoch 26/300
# 243/243 [==============================] - 0s 782us/step - loss: 20.0479
# Epoch 27/300
# 243/243 [==============================] - 0s 1ms/step - loss: 20.4530
# Epoch 28/300
# 243/243 [==============================] - 0s 2ms/step - loss: 19.6593
# Epoch 29/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.9919
# Epoch 30/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.7424
# Epoch 31/300
# 243/243 [==============================] - 0s 1ms/step - loss: 20.1370
# Epoch 32/300
# 243/243 [==============================] - 0s 1ms/step - loss: 20.6674
# Epoch 33/300
# 243/243 [==============================] - 0s 1ms/step - loss: 20.7335
# Epoch 34/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.9294
# Epoch 35/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.7520
# Epoch 36/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.0092
# Epoch 37/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.4418
# Epoch 38/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.8726
# Epoch 39/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.6336
# Epoch 40/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.4117
# Epoch 41/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.9980
# Epoch 42/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.2114
# Epoch 43/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.7137
# Epoch 44/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.5592
# Epoch 45/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.2912
# Epoch 46/300
# 243/243 [==============================] - 0s 1ms/step - loss: 19.2131
# Epoch 47/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.7655
# Epoch 48/300
# 243/243 [==============================] - 0s 990us/step - loss: 19.2828
# Epoch 49/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.6413
# Epoch 50/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.2100
# Epoch 51/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.5567
# Epoch 52/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.4787
# Epoch 53/300
# 243/243 [==============================] - 0s 985us/step - loss: 18.6916
# Epoch 54/300
# 243/243 [==============================] - 0s 991us/step - loss: 18.7513
# Epoch 55/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.7816
# Epoch 56/300
# 243/243 [==============================] - 0s 986us/step - loss: 18.2930
# Epoch 57/300
# 243/243 [==============================] - 0s 986us/step - loss: 18.5366
# Epoch 58/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.3806
# Epoch 59/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.2381
# Epoch 60/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.9651
# Epoch 61/300
# 243/243 [==============================] - 0s 985us/step - loss: 18.3740
# Epoch 62/300
# 243/243 [==============================] - 0s 978us/step - loss: 18.1343
# Epoch 63/300
# 243/243 [==============================] - 0s 980us/step - loss: 18.0497
# Epoch 64/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.0619
# Epoch 65/300
# 243/243 [==============================] - 0s 999us/step - loss: 18.0834
# Epoch 66/300
# 243/243 [==============================] - 0s 984us/step - loss: 18.0547
# Epoch 67/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.2707
# Epoch 68/300
# 243/243 [==============================] - 0s 965us/step - loss: 17.5757
# Epoch 69/300
# 243/243 [==============================] - 0s 993us/step - loss: 17.9658
# Epoch 70/300
# 243/243 [==============================] - 0s 996us/step - loss: 18.3798
# Epoch 71/300
# 243/243 [==============================] - 0s 988us/step - loss: 17.9299
# Epoch 72/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.8108
# Epoch 73/300
# 243/243 [==============================] - 0s 964us/step - loss: 18.0701
# Epoch 74/300
# 243/243 [==============================] - 0s 975us/step - loss: 17.7885
# Epoch 75/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.6747
# Epoch 76/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.9653
# Epoch 77/300
# 243/243 [==============================] - 0s 976us/step - loss: 17.8610
# Epoch 78/300
# 243/243 [==============================] - 0s 974us/step - loss: 17.6361
# Epoch 79/300
# 243/243 [==============================] - 0s 1ms/step - loss: 18.4147
# Epoch 80/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.9950
# Epoch 81/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.5445
# Epoch 82/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.5699
# Epoch 83/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.9088
# Epoch 84/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.4398
# Epoch 85/300
# 243/243 [==============================] - 0s 972us/step - loss: 17.4092
# Epoch 86/300
# 243/243 [==============================] - 0s 986us/step - loss: 17.4924
# Epoch 87/300
# 243/243 [==============================] - 0s 988us/step - loss: 17.6603
# Epoch 88/300
# 243/243 [==============================] - 0s 979us/step - loss: 17.9173
# Epoch 89/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.5323
# Epoch 90/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.7755
# Epoch 91/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.0502
# Epoch 92/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.3802
# Epoch 93/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.7898
# Epoch 94/300
# 243/243 [==============================] - 0s 994us/step - loss: 17.3425
# Epoch 95/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.1781
# Epoch 96/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.2339
# Epoch 97/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.0527
# Epoch 98/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.2426
# Epoch 99/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.5763
# Epoch 100/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.5881
# Epoch 101/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.8696
# Epoch 102/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.1579
# Epoch 103/300
# 243/243 [==============================] - 0s 967us/step - loss: 17.2110
# Epoch 104/300
# 243/243 [==============================] - 0s 981us/step - loss: 17.4002
# Epoch 105/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.7043
# Epoch 106/300
# 243/243 [==============================] - 0s 968us/step - loss: 17.0752
# Epoch 107/300
# 243/243 [==============================] - 0s 987us/step - loss: 17.1527
# Epoch 108/300
# 243/243 [==============================] - 0s 993us/step - loss: 17.1002
# Epoch 109/300
# 243/243 [==============================] - 0s 964us/step - loss: 17.3364
# Epoch 110/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.2528
# Epoch 111/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.3859
# Epoch 112/300
# 243/243 [==============================] - 0s 973us/step - loss: 17.3438
# Epoch 113/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.4749
# Epoch 114/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.4315
# Epoch 115/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.3502
# Epoch 116/300
# 243/243 [==============================] - 0s 994us/step - loss: 17.0383
# Epoch 117/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.3951
# Epoch 118/300
# 243/243 [==============================] - 0s 996us/step - loss: 17.2672
# Epoch 119/300
# 243/243 [==============================] - 0s 987us/step - loss: 17.0447
# Epoch 120/300
# 243/243 [==============================] - 0s 990us/step - loss: 17.1110
# Epoch 121/300
# 243/243 [==============================] - 0s 956us/step - loss: 17.0761
# Epoch 122/300
# 243/243 [==============================] - 0s 991us/step - loss: 16.9239
# Epoch 123/300
# 243/243 [==============================] - 0s 983us/step - loss: 16.6666
# Epoch 124/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.2760
# Epoch 125/300
# 243/243 [==============================] - 0s 963us/step - loss: 17.0156
# Epoch 126/300
# 243/243 [==============================] - 0s 992us/step - loss: 16.7545
# Epoch 127/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.0778
# Epoch 128/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.7345
# Epoch 129/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.5689
# Epoch 130/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.9742
# Epoch 131/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.8831
# Epoch 132/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.6860
# Epoch 133/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.8125
# Epoch 134/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.7936
# Epoch 135/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.7055
# Epoch 136/300
# 243/243 [==============================] - 0s 974us/step - loss: 16.5910
# Epoch 137/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.6986
# Epoch 138/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.6130
# Epoch 139/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.8413
# Epoch 140/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.1400
# Epoch 141/300
# 243/243 [==============================] - 0s 1ms/step - loss: 17.0836
# Epoch 142/300
# 243/243 [==============================] - 0s 983us/step - loss: 16.9282
# Epoch 143/300
# 243/243 [==============================] - 0s 966us/step - loss: 16.4809
# Epoch 144/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.6362
# Epoch 145/300
# 243/243 [==============================] - 0s 999us/step - loss: 16.9574
# Epoch 146/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.5805
# Epoch 147/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.6770
# Epoch 148/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.7475
# Epoch 149/300
# 243/243 [==============================] - 0s 992us/step - loss: 16.5456
# Epoch 150/300
# 243/243 [==============================] - 0s 997us/step - loss: 16.5537
# Epoch 151/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.6706
# Epoch 152/300
# 243/243 [==============================] - 0s 989us/step - loss: 16.6774
# Epoch 153/300
# 243/243 [==============================] - 0s 973us/step - loss: 16.5786
# Epoch 154/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.4092
# Epoch 155/300
# 243/243 [==============================] - 0s 978us/step - loss: 16.4879
# Epoch 156/300
# 243/243 [==============================] - 0s 977us/step - loss: 16.6059
# Epoch 157/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.3976
# Epoch 158/300
# 243/243 [==============================] - 0s 993us/step - loss: 16.3882
# Epoch 159/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.8056
# Epoch 160/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.3384
# Epoch 161/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.5096
# Epoch 162/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.5621
# Epoch 163/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.7503
# Epoch 164/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.3093
# Epoch 165/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.5177
# Epoch 166/300
# 243/243 [==============================] - 0s 974us/step - loss: 16.3631
# Epoch 167/300
# 243/243 [==============================] - 0s 986us/step - loss: 16.4916
# Epoch 168/300
# 243/243 [==============================] - 0s 985us/step - loss: 16.6937
# Epoch 169/300
# 243/243 [==============================] - 0s 982us/step - loss: 16.1519
# Epoch 170/300
# 243/243 [==============================] - 0s 997us/step - loss: 16.1675
# Epoch 171/300
# 243/243 [==============================] - 0s 982us/step - loss: 16.6583
# Epoch 172/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.4829
# Epoch 173/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0073
# Epoch 174/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1210
# Epoch 175/300
# 243/243 [==============================] - 0s 993us/step - loss: 16.5221
# Epoch 176/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.3109
# Epoch 177/300
# 243/243 [==============================] - 0s 985us/step - loss: 16.0739
# Epoch 178/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.6636
# Epoch 179/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.3191
# Epoch 180/300
# 243/243 [==============================] - 0s 1000us/step - loss: 16.1739
# Epoch 181/300
# 243/243 [==============================] - 0s 959us/step - loss: 16.4205
# Epoch 182/300
# 243/243 [==============================] - 0s 990us/step - loss: 16.1540
# Epoch 183/300
# 243/243 [==============================] - 0s 981us/step - loss: 16.7142
# Epoch 184/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1860
# Epoch 185/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0742
# Epoch 186/300
# 243/243 [==============================] - 0s 986us/step - loss: 16.2194
# Epoch 187/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1343
# Epoch 188/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.2141
# Epoch 189/300
# 243/243 [==============================] - 0s 976us/step - loss: 16.0600
# Epoch 190/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.2511
# Epoch 191/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.5522
# Epoch 192/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1883
# Epoch 193/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0235
# Epoch 194/300
# 243/243 [==============================] - 0s 978us/step - loss: 15.9334
# Epoch 195/300
# 243/243 [==============================] - 0s 987us/step - loss: 16.3321
# Epoch 196/300
# 243/243 [==============================] - 0s 987us/step - loss: 16.1653
# Epoch 197/300
# 243/243 [==============================] - 0s 971us/step - loss: 15.9563
# Epoch 198/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1650
# Epoch 199/300
# 243/243 [==============================] - 0s 994us/step - loss: 16.0689
# Epoch 200/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0781
# Epoch 201/300
# 243/243 [==============================] - 0s 967us/step - loss: 16.2767
# Epoch 202/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0417
# Epoch 203/300
# 243/243 [==============================] - 0s 996us/step - loss: 16.0880
# Epoch 204/300
# 243/243 [==============================] - 0s 985us/step - loss: 16.2506
# Epoch 205/300
# 243/243 [==============================] - 0s 980us/step - loss: 15.8831
# Epoch 206/300
# 243/243 [==============================] - 0s 977us/step - loss: 16.1033
# Epoch 207/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.2622
# Epoch 208/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0344
# Epoch 209/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.5837
# Epoch 210/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8753
# Epoch 211/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8274
# Epoch 212/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0842
# Epoch 213/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0153
# Epoch 214/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9239
# Epoch 215/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9988
# Epoch 216/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9393
# Epoch 217/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8114
# Epoch 218/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0538
# Epoch 219/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9097
# Epoch 220/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.7759
# Epoch 221/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7616
# Epoch 222/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0380
# Epoch 223/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0526
# Epoch 224/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8624
# Epoch 225/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0258
# Epoch 226/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7718
# Epoch 227/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8516
# Epoch 228/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8748
# Epoch 229/300
# 243/243 [==============================] - 0s 989us/step - loss: 15.6509
# Epoch 230/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0629
# Epoch 231/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7453
# Epoch 232/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1280
# Epoch 233/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0125
# Epoch 234/300
# 243/243 [==============================] - 0s 978us/step - loss: 16.1137
# Epoch 235/300
# 243/243 [==============================] - 0s 991us/step - loss: 16.3012
# Epoch 236/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1582
# Epoch 237/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.3608
# Epoch 238/300
# 243/243 [==============================] - 0s 986us/step - loss: 16.0122
# Epoch 239/300
# 243/243 [==============================] - 0s 974us/step - loss: 15.9140
# Epoch 240/300
# 243/243 [==============================] - 0s 974us/step - loss: 16.0489
# Epoch 241/300
# 243/243 [==============================] - 0s 972us/step - loss: 16.1644
# Epoch 242/300
# 243/243 [==============================] - 0s 990us/step - loss: 15.8346
# Epoch 243/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9442
# Epoch 244/300
# 243/243 [==============================] - 0s 983us/step - loss: 16.0429
# Epoch 245/300
# 243/243 [==============================] - 0s 957us/step - loss: 15.8620
# Epoch 246/300
# 243/243 [==============================] - 0s 981us/step - loss: 16.1992
# Epoch 247/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8690
# Epoch 248/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.2087
# Epoch 249/300
# 243/243 [==============================] - 0s 998us/step - loss: 16.2311
# Epoch 250/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7316
# Epoch 251/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9325
# Epoch 252/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0733
# Epoch 253/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9188
# Epoch 254/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.5623
# Epoch 255/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.5638
# Epoch 256/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8821
# Epoch 257/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8813
# Epoch 258/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.3240
# Epoch 259/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.9226
# Epoch 260/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.5469
# Epoch 261/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8181
# Epoch 262/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0154
# Epoch 263/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7771
# Epoch 264/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7815
# Epoch 265/300
# 243/243 [==============================] - 0s 997us/step - loss: 15.7499
# Epoch 266/300
# 243/243 [==============================] - 0s 981us/step - loss: 15.8171
# Epoch 267/300
# 243/243 [==============================] - 0s 984us/step - loss: 16.0183
# Epoch 268/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.2361
# Epoch 269/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0071
# Epoch 270/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.2366
# Epoch 271/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8128
# Epoch 272/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.6792
# Epoch 273/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.0067
# Epoch 274/300
# 243/243 [==============================] - 0s 1ms/step - loss: 16.1537
# Epoch 275/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7309
# Epoch 276/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7471
# Epoch 277/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8538
# Epoch 278/300
# 243/243 [==============================] - 0s 983us/step - loss: 15.6526
# Epoch 279/300
# 243/243 [==============================] - 0s 978us/step - loss: 15.7065
# Epoch 280/300
# 243/243 [==============================] - 0s 970us/step - loss: 15.6431
# Epoch 281/300
# 243/243 [==============================] - 0s 999us/step - loss: 15.7933
# Epoch 282/300
# 243/243 [==============================] - 0s 998us/step - loss: 15.7357
# Epoch 283/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.4684
# Epoch 284/300
# 243/243 [==============================] - 0s 993us/step - loss: 15.8671
# Epoch 285/300
# 243/243 [==============================] - 0s 987us/step - loss: 15.8233
# Epoch 286/300
# 243/243 [==============================] - 0s 972us/step - loss: 15.8798
# Epoch 287/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.4968
# Epoch 288/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8251
# Epoch 289/300
# 243/243 [==============================] - 0s 988us/step - loss: 15.6089
# Epoch 290/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.6079
# Epoch 291/300
# 243/243 [==============================] - 0s 975us/step - loss: 15.4368
# Epoch 292/300
# 243/243 [==============================] - 0s 1000us/step - loss: 15.6087
# Epoch 293/300
# 243/243 [==============================] - 0s 969us/step - loss: 15.8250
# Epoch 294/300
# 243/243 [==============================] - 0s 968us/step - loss: 15.8020
# Epoch 295/300
# 243/243 [==============================] - 0s 998us/step - loss: 15.7127
# Epoch 296/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.8458
# Epoch 297/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.5068
# Epoch 298/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.5081
# Epoch 299/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.7867
# Epoch 300/300
# 243/243 [==============================] - 0s 1ms/step - loss: 15.6584

# %% [markdown]
# Demonstrate training

# %%
yhat = model.predict(X)

# %%
plt.plot(y)
plt.plot(yhat)
plt.show()

# %% [markdown]
# Demonstrate prediction

# %%
yhat = model.predict(X_test)

# %%
print(f"Predicted: {yhat[0][0]:.2f}  Expected: {y_expected[0][0]:.2f}")
# Out:
# Predicted: 447.97  Expected: 453.31

# %% [markdown]
# **THIS IS NOT AN INVESTMENT ADVICE!**
