# %% [markdown]
# # Multivariate Multiheaded 1D CNN Example

# %% [markdown]
# Based on:
# * [Time Series Forecasting on Stock Prices](https://www.youtube.com/watch?v=j05UUs99eNQ) from [Coding Tech](https://www.youtube.com/channel/UCtxCXg-UvSnTKPOzLH4wJaQ)
# * https://machinelearningmastery.com/how-to-develop-convolutional-neural-network-models-for-time-series-forecasting/

# %% [markdown]
# **Disclaimer:** _Investing in the stock market involves risk and can lead to monetary loss. This material is purely for educational purposes and should not be taken as professional investment advice. Invest at your own discretion._

# %% [markdown]
# Import the libraries

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, concatenate

import matplotlib.pyplot as plt

# %% [markdown]
# Load the data

# %%
df = pd.read_csv("SP500.csv")

# %% [markdown]
# Show the data

# %%
df
# Out:
#             Date        Open        High         Low       Close   Volume  \
# 0     2000-05-19   96.106028   96.106028   94.484962   94.779701   775500
# 1     2000-05-22   94.716551   94.716551   92.169162   94.190231  1850600
# 2     2000-05-23   94.463952   94.463952   92.758675   92.758675   373900
# 3     2000-05-24   92.800753   94.358660   92.063905   94.148132   400300
# 4     2000-05-25   94.337613   94.948145   92.884970   93.284973    69600
# ...          ...         ...         ...         ...         ...      ...
# 5359  2021-09-08  452.899994  453.679993  450.869995  453.000000  4076800
# 5360  2021-09-09  452.690002  454.579987  450.730011  450.980011  3851600
# 5361  2021-09-10  453.059998  453.510010  447.299988  447.540009  3023500
# 5362  2021-09-13  450.679993  450.929993  446.089996  448.579987  3007400
# 5363  2021-09-14  450.079987  450.320007  445.200012  446.190002  3658400
#
#       Dividends  Stock Splits
# 0           0.0             0
# 1           0.0             0
# 2           0.0             0
# 3           0.0             0
# 4           0.0             0
# ...         ...           ...
# 5359        0.0             0
# 5360        0.0             0
# 5361        0.0             0
# 5362        0.0             0
# 5363        0.0             0
#
# [5364 rows x 8 columns]

# %% [markdown]
# Add indices for every day in the period

# %%
start_date = df.Date.min()
end_date = df.Date.max()

# %%
df_date = pd.date_range(start=start_date, end=end_date).to_frame(name="Date")
df_date.reset_index(drop=True, inplace=True)

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.merge(df_date, how='right')

# %% [markdown]
# Interpolate missing values

# %%
df = df.interpolate(method='linear', limit_direction='both')

# %% [markdown]
# Remove not needed columns

# %%
df = df[['Date', 'Close']].copy()

# %%
df
# Out:
#            Date       Close
# 0    2000-05-19   94.779701
# 1    2000-05-20   94.583211
# 2    2000-05-21   94.386721
# 3    2000-05-22   94.190231
# 4    2000-05-23   92.758675
# ...         ...         ...
# 7784 2021-09-10  447.540009
# 7785 2021-09-11  447.886668
# 7786 2021-09-12  448.233327
# 7787 2021-09-13  448.579987
# 7788 2021-09-14  446.190002
#
# [7789 rows x 2 columns]

# %% [markdown]
# **Simple Moving Average**
# * Example periods: 15, 30 or 45 days

# %%
def computeSMA(data, period, column='Close'):
    return data[column].rolling(window=period).mean()

# %%
df['SMA'] = computeSMA(df, period=15)

# %% [markdown]
# **Exponential Moving Averages**
# * Example periods: 15, 30 or 45 days

# %%
def computeEMA(data, period, column='Close'):
    return data[column].ewm(span=period, adjust=False).mean()

# %%
df['EMA'] = computeEMA(df, period=15)

# %% [markdown]
# **Relative Strength Index**

# %%
def computeRSI(data, period=14, column='Close'):
    delta = data[column].diff(1)
    delta = delta.dropna()
    up = delta.copy()
    down = delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0
    data['up'] = up
    data['down'] = down
    AVG_Gain = computeSMA(data, period, column='up')
    AVG_Loss = abs(computeSMA(data, period, column='down'))
    RS = AVG_Gain / AVG_Loss
    RSI = 100.0 - (100.0 / (1.0 + RS))
    return RSI

# %%
df['RSI'] = computeRSI(df, period=14)

# %% [markdown]
# **Moving Average Convergence Divergence**

# %%
def MACD(data, period1=26, period2=12, signal=9, column='Close'):
    exp1 = computeEMA(data,period1, column=column)
    exp2 = computeEMA(data,period2, column=column)
    data['MACD'] = exp2 - exp1
    data['Signal Line'] = computeSMA(data, signal, column='MACD')

# %%
MACD(df)

# %% [markdown]
# Remove NaNs

# %%
df = df.dropna()

# %%
df
# Out:
#            Date       Close         SMA         EMA        up      down  \
# 14   2000-06-02   99.663971   94.910938   95.600925  1.936874  0.000000
# 15   2000-06-03   99.446431   95.222053   96.081613  0.000000 -0.217539
# 16   2000-06-04   99.228892   95.531765   96.475023  0.000000 -0.217539
# 17   2000-06-05   99.011353   95.840074   96.792064  0.000000 -0.217539
# 18   2000-06-06   98.506065   96.127796   97.006314  0.000000 -0.505287
# ...         ...         ...         ...         ...       ...       ...
# 7784 2021-09-10  447.540009  453.257671  451.878931  0.000000 -3.440002
# 7785 2021-09-11  447.886668  452.970782  451.379898  0.346659  0.000000
# 7786 2021-09-12  448.233327  452.662337  450.986577  0.346659  0.000000
# 7787 2021-09-13  448.579987  452.332335  450.685753  0.346659  0.000000
# 7788 2021-09-14  446.190002  451.798335  450.123784  0.000000 -2.389984
#
#             RSI      MACD  Signal Line
# 14    71.245582  0.680463    -0.042866
# 15    71.115354  0.916439     0.090681
# 16    70.985601  1.073524     0.250695
# 17    70.856321  1.167008     0.420929
# 18    77.029581  1.186644     0.585988
# ...         ...       ...          ...
# 7784  30.279938  1.487905     2.619024
# 7785  28.313930  1.046934     2.394046
# 7786  26.233827  0.717167     2.129901
# 7787  24.029401  0.478284     1.844411
# 7788  20.440156  0.095020     1.527523
#
# [7775 rows x 9 columns]

# %% [markdown]
# Separate a multivariate sequence into samples

# %%
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # Find the end of the pattern
        end_ix = i + n_steps
        # Check if we are bound by sequence
        if end_ix > len(sequences) - 1:
            break
        # Gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1, -1]
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %% [markdown]
# Define input sequence

# %%
in_seq1 = df['SMA'].values
in_seq2 = df['EMA'].values
in_seq3 = df['RSI'].values
in_seq4 = df['MACD'].values
in_seq5 = df['Signal Line'].values
out_seq = df['Close'].values

# %% [markdown]
# Convert to [rows, columns] structure

# %%
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
in_seq3 = in_seq3.reshape((len(in_seq3), 1))
in_seq4 = in_seq4.reshape((len(in_seq4), 1))
in_seq5 = in_seq5.reshape((len(in_seq5), 1))
out_seq = out_seq.reshape((len(out_seq), 1))

# %% [markdown]
# Horizontally stack columns

# %%
dataset = np.hstack((in_seq1, in_seq2, in_seq3, in_seq4, in_seq5, out_seq))

# %% [markdown]
# Choose a number of time steps

# %%
n_steps = 10

# %% [markdown]
# Convert into input/output

# %%
X, y = split_sequences(dataset, n_steps)

# %% [markdown]
# One time series per head

# %%
n_features = 1

# %% [markdown]
# Separate input data

# %%
X1 = X[:, :, 0].reshape(X.shape[0], X.shape[1], n_features)
X2 = X[:, :, 1].reshape(X.shape[0], X.shape[1], n_features)
X3 = X[:, :, 2].reshape(X.shape[0], X.shape[1], n_features)
X4 = X[:, :, 3].reshape(X.shape[0], X.shape[1], n_features)
X5 = X[:, :, 4].reshape(X.shape[0], X.shape[1], n_features)

# %% [markdown]
# Set test data

# %%
test_size = n_steps
prediction_size = n_features
y_test = y[-test_size-prediction_size:-prediction_size]
X1_test = X1[-test_size-prediction_size:-prediction_size]
X2_test = X2[-test_size-prediction_size:-prediction_size]
X3_test = X3[-test_size-prediction_size:-prediction_size]
X4_test = X4[-test_size-prediction_size:-prediction_size]
X5_test = X5[-test_size-prediction_size:-prediction_size]

# %%
y_expected = y[-prediction_size:]

# %%
y = y[:-test_size-prediction_size]
X1 = X1[:-test_size-prediction_size]
X2 = X2[:-test_size-prediction_size]
X3 = X3[:-test_size-prediction_size]
X4 = X4[:-test_size-prediction_size]
X5 = X5[:-test_size-prediction_size]

# %% [markdown]
# Define models

# %%
visible1 = Input(shape=(n_steps, n_features))
cnn1 = Conv1D(filters=64, kernel_size=2, activation='relu')(visible1)
cnn1 = MaxPooling1D(pool_size=2)(cnn1)
cnn1 = Flatten()(cnn1)

# %%
visible2 = Input(shape=(n_steps, n_features))
cnn2 = Conv1D(filters=64, kernel_size=2, activation='relu')(visible2)
cnn2 = MaxPooling1D(pool_size=2)(cnn2)
cnn2 = Flatten()(cnn2)

# %%
visible3 = Input(shape=(n_steps, n_features))
cnn3 = Conv1D(filters=64, kernel_size=2, activation='relu')(visible3)
cnn3 = MaxPooling1D(pool_size=2)(cnn3)
cnn3 = Flatten()(cnn3)

# %%
visible4 = Input(shape=(n_steps, n_features))
cnn4 = Conv1D(filters=64, kernel_size=2, activation='relu')(visible4)
cnn4 = MaxPooling1D(pool_size=2)(cnn4)
cnn4 = Flatten()(cnn4)

# %%
visible5 = Input(shape=(n_steps, n_features))
cnn5 = Conv1D(filters=64, kernel_size=2, activation='relu')(visible5)
cnn5 = MaxPooling1D(pool_size=2)(cnn5)
cnn5 = Flatten()(cnn5)

# %% [markdown]
# Merge input models

# %%
merge = concatenate([cnn1, cnn2, cnn3, cnn4, cnn5])
dense = Dense(50, activation='relu')(merge)
output = Dense(1)(dense)
model = Model(inputs=[visible1, visible2, visible3, visible4, visible5], outputs=output)

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# Fit model

# %%
model.fit([X1, X2, X3, X4, X5], y, epochs=300)
# Out:
# Epoch 1/300
# 243/243 [==============================] - 1s 2ms/step - loss: 886.4467
# Epoch 2/300
# 243/243 [==============================] - 1s 2ms/step - loss: 11.8260
# Epoch 3/300
# 243/243 [==============================] - 1s 2ms/step - loss: 9.1432
# Epoch 4/300
# 243/243 [==============================] - 1s 2ms/step - loss: 7.5578
# Epoch 5/300
# 243/243 [==============================] - 1s 2ms/step - loss: 6.7422
# Epoch 6/300
# 243/243 [==============================] - 1s 2ms/step - loss: 6.2184
# Epoch 7/300
# 243/243 [==============================] - 1s 2ms/step - loss: 6.1107
# Epoch 8/300
# 243/243 [==============================] - 1s 2ms/step - loss: 6.5577
# Epoch 9/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.9432
# Epoch 10/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.5445
# Epoch 11/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.7586
# Epoch 12/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.1267
# Epoch 13/300
# 243/243 [==============================] - 1s 2ms/step - loss: 6.3101
# Epoch 14/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.1649
# Epoch 15/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.6304
# Epoch 16/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.2095
# Epoch 17/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.8644
# Epoch 18/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.0715
# Epoch 19/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.1401
# Epoch 20/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.2291
# Epoch 21/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.3598
# Epoch 22/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.2825
# Epoch 23/300
# 243/243 [==============================] - 1s 2ms/step - loss: 6.3939
# Epoch 24/300
# 243/243 [==============================] - 1s 2ms/step - loss: 6.0382
# Epoch 25/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.5047
# Epoch 26/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.3676
# Epoch 27/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.2522
# Epoch 28/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.4746
# Epoch 29/300
# 243/243 [==============================] - 1s 3ms/step - loss: 5.1478
# Epoch 30/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.3770
# Epoch 31/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.4486
# Epoch 32/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.2638
# Epoch 33/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.0567
# Epoch 34/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.5758
# Epoch 35/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.1385
# Epoch 36/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.2010
# Epoch 37/300
# 243/243 [==============================] - 1s 3ms/step - loss: 4.2256
# Epoch 38/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.1974
# Epoch 39/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.3222
# Epoch 40/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.7233
# Epoch 41/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.4543
# Epoch 42/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.6378
# Epoch 43/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.2078
# Epoch 44/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.9976
# Epoch 45/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.0727
# Epoch 46/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.8874
# Epoch 47/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.8265
# Epoch 48/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.9688
# Epoch 49/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.8327
# Epoch 50/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.9066
# Epoch 51/300
# 243/243 [==============================] - 1s 2ms/step - loss: 5.3024
# Epoch 52/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.1905
# Epoch 53/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.6984
# Epoch 54/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.7222
# Epoch 55/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.0489
# Epoch 56/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.6295
# Epoch 57/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.5525
# Epoch 58/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.8826
# Epoch 59/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.6382
# Epoch 60/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.5857
# Epoch 61/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4318
# Epoch 62/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.7535
# Epoch 63/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4948
# Epoch 64/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.5190
# Epoch 65/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.7084
# Epoch 66/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.5847
# Epoch 67/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1186
# Epoch 68/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3211
# Epoch 69/300
# 243/243 [==============================] - 0s 2ms/step - loss: 4.2066
# Epoch 70/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.3202
# Epoch 71/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.6437
# Epoch 72/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4745
# Epoch 73/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.7381
# Epoch 74/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3713
# Epoch 75/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4316
# Epoch 76/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.6370
# Epoch 77/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4713
# Epoch 78/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0594
# Epoch 79/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.8861
# Epoch 80/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.5801
# Epoch 81/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.5955
# Epoch 82/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.8577
# Epoch 83/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1807
# Epoch 84/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3981
# Epoch 85/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.2883
# Epoch 86/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4998
# Epoch 87/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.2479
# Epoch 88/300
# 243/243 [==============================] - 0s 2ms/step - loss: 4.1745
# Epoch 89/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1528
# Epoch 90/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3113
# Epoch 91/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3208
# Epoch 92/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.3964
# Epoch 93/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.4340
# Epoch 94/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.6621
# Epoch 95/300
# 243/243 [==============================] - 1s 3ms/step - loss: 3.1796
# Epoch 96/300
# 243/243 [==============================] - 1s 2ms/step - loss: 4.3697
# Epoch 97/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.6919
# Epoch 98/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1318
# Epoch 99/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1848
# Epoch 100/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.6085
# Epoch 101/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.0966
# Epoch 102/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1348
# Epoch 103/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.0626
# Epoch 104/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4319
# Epoch 105/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1107
# Epoch 106/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.7740
# Epoch 107/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1457
# Epoch 108/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.0186
# Epoch 109/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.0237
# Epoch 110/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1797
# Epoch 111/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7750
# Epoch 112/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1455
# Epoch 113/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.0697
# Epoch 114/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.3148
# Epoch 115/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.2222
# Epoch 116/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.2729
# Epoch 117/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1387
# Epoch 118/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1827
# Epoch 119/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8220
# Epoch 120/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.2155
# Epoch 121/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1267
# Epoch 122/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0575
# Epoch 123/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3135
# Epoch 124/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9973
# Epoch 125/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0948
# Epoch 126/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1452
# Epoch 127/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8109
# Epoch 128/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8673
# Epoch 129/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.2482
# Epoch 130/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.6412
# Epoch 131/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1214
# Epoch 132/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1853
# Epoch 133/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4633
# Epoch 134/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.2354
# Epoch 135/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0575
# Epoch 136/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7463
# Epoch 137/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1931
# Epoch 138/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3446
# Epoch 139/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7477
# Epoch 140/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8827
# Epoch 141/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9464
# Epoch 142/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1638
# Epoch 143/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.2107
# Epoch 144/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.7219
# Epoch 145/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0434
# Epoch 146/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8604
# Epoch 147/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0860
# Epoch 148/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9528
# Epoch 149/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8417
# Epoch 150/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0119
# Epoch 151/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8703
# Epoch 152/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.7347
# Epoch 153/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7047
# Epoch 154/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1265
# Epoch 155/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0685
# Epoch 156/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9066
# Epoch 157/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0782
# Epoch 158/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7384
# Epoch 159/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8251
# Epoch 160/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.2687
# Epoch 161/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7161
# Epoch 162/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9498
# Epoch 163/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9775
# Epoch 164/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4743
# Epoch 165/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0175
# Epoch 166/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8670
# Epoch 167/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8824
# Epoch 168/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0795
# Epoch 169/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9899
# Epoch 170/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9872
# Epoch 171/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7743
# Epoch 172/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6668
# Epoch 173/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0175
# Epoch 174/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.2875
# Epoch 175/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7259
# Epoch 176/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8156
# Epoch 177/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9991
# Epoch 178/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9305
# Epoch 179/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8853
# Epoch 180/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8070
# Epoch 181/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3340
# Epoch 182/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.1704
# Epoch 183/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8167
# Epoch 184/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6801
# Epoch 185/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0558
# Epoch 186/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0455
# Epoch 187/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7969
# Epoch 188/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9099
# Epoch 189/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9885
# Epoch 190/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6830
# Epoch 191/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8620
# Epoch 192/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7031
# Epoch 193/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8352
# Epoch 194/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6686
# Epoch 195/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9746
# Epoch 196/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9024
# Epoch 197/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8273
# Epoch 198/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.9566
# Epoch 199/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1631
# Epoch 200/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0256
# Epoch 201/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3865
# Epoch 202/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.3106
# Epoch 203/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7953
# Epoch 204/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0604
# Epoch 205/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6501
# Epoch 206/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4164
# Epoch 207/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6904
# Epoch 208/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8224
# Epoch 209/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.9528
# Epoch 210/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8802
# Epoch 211/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8424
# Epoch 212/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7573
# Epoch 213/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6357
# Epoch 214/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8236
# Epoch 215/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7340
# Epoch 216/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.0281
# Epoch 217/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7920
# Epoch 218/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9943
# Epoch 219/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.5837
# Epoch 220/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7441
# Epoch 221/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.0233
# Epoch 222/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7152
# Epoch 223/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8236
# Epoch 224/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.2736
# Epoch 225/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.6200
# Epoch 226/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6311
# Epoch 227/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7870
# Epoch 228/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8131
# Epoch 229/300
# 243/243 [==============================] - 1s 3ms/step - loss: 2.5848
# Epoch 230/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8303
# Epoch 231/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7811
# Epoch 232/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.8454
# Epoch 233/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.5786
# Epoch 234/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7405
# Epoch 235/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.9224
# Epoch 236/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7877
# Epoch 237/300
# 243/243 [==============================] - 1s 2ms/step - loss: 3.0044
# Epoch 238/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.6918
# Epoch 239/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7181
# Epoch 240/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.1493
# Epoch 241/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7841
# Epoch 242/300
# 243/243 [==============================] - 0s 2ms/step - loss: 3.4625
# Epoch 243/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8730
# Epoch 244/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6229
# Epoch 245/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.6396
# Epoch 246/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6240
# Epoch 247/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.9887
# Epoch 248/300
# 243/243 [==============================] - 1s 2ms/step - loss: 2.7620
# Epoch 249/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6393
# Epoch 250/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7503
# Epoch 251/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8109
# Epoch 252/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9046
# Epoch 253/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7854
# Epoch 254/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.5525
# Epoch 255/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8823
# Epoch 256/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7160
# Epoch 257/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9348
# Epoch 258/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7908
# Epoch 259/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6419
# Epoch 260/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.9003
# Epoch 261/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.7804
# Epoch 262/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.8041
# Epoch 263/300
# 243/243 [==============================] - 0s 2ms/step - loss: 2.6127
# Epoch 264/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.7185
# Epoch 265/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.6017
# Epoch 266/300
# 243/243 [==============================] - 0s 995us/step - loss: 2.6408
# Epoch 267/300
# 243/243 [==============================] - 0s 984us/step - loss: 2.7715
# Epoch 268/300
# 243/243 [==============================] - 0s 982us/step - loss: 2.6815
# Epoch 269/300
# 243/243 [==============================] - 0s 985us/step - loss: 2.7028
# Epoch 270/300
# 243/243 [==============================] - 0s 978us/step - loss: 2.7854
# Epoch 271/300
# 243/243 [==============================] - 0s 1ms/step - loss: 3.1080
# Epoch 272/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.7247
# Epoch 273/300
# 243/243 [==============================] - 0s 983us/step - loss: 3.0853
# Epoch 274/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.5414
# Epoch 275/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.8840
# Epoch 276/300
# 243/243 [==============================] - 0s 988us/step - loss: 2.7165
# Epoch 277/300
# 243/243 [==============================] - 0s 983us/step - loss: 2.7557
# Epoch 278/300
# 243/243 [==============================] - 0s 979us/step - loss: 2.7060
# Epoch 279/300
# 243/243 [==============================] - 0s 999us/step - loss: 2.8419
# Epoch 280/300
# 243/243 [==============================] - 0s 998us/step - loss: 2.7000
# Epoch 281/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.6234
# Epoch 282/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.6787
# Epoch 283/300
# 243/243 [==============================] - 0s 1ms/step - loss: 3.2956
# Epoch 284/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.9753
# Epoch 285/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.4890
# Epoch 286/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.8422
# Epoch 287/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.6291
# Epoch 288/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.7501
# Epoch 289/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.8510
# Epoch 290/300
# 243/243 [==============================] - 0s 1ms/step - loss: 2.5782
# Epoch 291/300
# 243/243 [==============================] - 0s 984us/step - loss: 2.6781
# Epoch 292/300
# 243/243 [==============================] - 0s 975us/step - loss: 2.6303
# Epoch 293/300
# 243/243 [==============================] - 0s 983us/step - loss: 2.7461
# Epoch 294/300
# 243/243 [==============================] - 0s 991us/step - loss: 2.6308
# Epoch 295/300
# 243/243 [==============================] - 0s 972us/step - loss: 2.7636
# Epoch 296/300
# 243/243 [==============================] - 0s 989us/step - loss: 2.6775
# Epoch 297/300
# 243/243 [==============================] - 0s 986us/step - loss: 2.7318
# Epoch 298/300
# 243/243 [==============================] - 0s 987us/step - loss: 2.6880
# Epoch 299/300
# 243/243 [==============================] - 0s 975us/step - loss: 2.6631
# Epoch 300/300
# 243/243 [==============================] - 0s 973us/step - loss: 2.5939

# %% [markdown]
# Demonstrate prediction

# %%
yhat = model.predict([X1, X2, X3, X4, X5])

# %%
plt.plot(y)
plt.plot(yhat)
plt.show()

# %% [markdown]
# Demonstrate prediction

# %%
yhat = model.predict([X1_test,X2_test, X3_test, X4_test, X5_test])

# %%
print(f"Predicted: {yhat[0][0]:.2f}  Expected: {y_expected[0]:.2f}")
# Out:
# Predicted: 455.42  Expected: 448.58

# %% [markdown]
# **THIS IS NOT AN INVESTMENT ADVICE!**
